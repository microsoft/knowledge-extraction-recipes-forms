# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.

# %% [markdown]
# Licensed under the MIT License.

# %% [markdown]
# # Form Recognizer Scoring Pipeline
#
# This notebook covers the process of setting up and running an AML pipeline that will score a custom form recognizer model.
#
# Steps in this notebook include:
#
# - Clapperboard Selection Step using OCR
# - Form Extraction step (scoring)
# - Postprocessing Step

# %% [markdown]
# ## Import Dependencies

# %%
#Load dotenv extension

# %load_ext dotenv
# %dotenv

import os
from os.path import join
import sys

sys.path.append("../")

import pandas as pd
import numpy as np

from azureml.core import Environment, Datastore, Workspace, Experiment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.data.data_reference import DataReference
from azureml.pipeline.core import Pipeline, PipelineData, PipelineParameter
from azureml.pipeline.steps import PythonScriptStep
from azureml.core.runconfig import RunConfiguration


from mlops.common.attach_compute import get_compute
from mlops.common.get_datastores import get_blob_datastore
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (cryptography 3.2 (c:\miniconda\envs\py37_default\lib\site-packages), Requirement.parse('cryptography<4.0.0,>=3.3.1; extra == "crypto"'), {'PyJWT'}).

# %% [markdown]
# ## Configure Workspace and Set Compute Target

# %%
# Restore AML workspace from config.json file (can be downloaded through the portal)

ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep = '\n')
# Out:
# Workspace name: sandbox
# Azure region: westus
# Subscription id: 5eb4ea0a-0c5d-4ed1-8553-b0ee0f5215b7
# Resource group: iota-sharing-rg

# %%
# Set compute target

compute_target = get_compute(
    workspace=ws,
    compute_name=os.getenv("AML_CLUSTER_NAME"),
    vm_size=os.getenv("AML_CLUSTER_CPU_SKU"),
    vm_priority=os.environ.get("AML_CLUSTER_PRIORITY", 'lowpriority'), 
    min_nodes=int(os.environ.get("AML_CLUSTER_MIN_NODES", 0)),
    max_nodes=int(os.environ.get("AML_CLUSTER_MAX_NODES", 4)),
    scale_down=int(os.environ.get("AML_CLUSTER_SCALE_DOWN", 600)),
)

# %% [markdown]
# ## Configure Datastores

# %%
#create root datastore
#datastore should represent storage container where data will be accessed
root_datastore = get_blob_datastore(ws, os.getenv("BLOB_DATASTORE_NAME"), os.getenv("STORAGE_NAME"),
                                    os.getenv("STORAGE_KEY"), os.getenv("STORAGE_CONTAINER"))

# Create input and output data references
# WARNING! DataReference works up to 12x times faster than Dataset
root_dir = DataReference(
    datastore=root_datastore, 
    data_reference_name="form_data_ref", 
    mode="mount"
)

# %% [markdown]
# ## Set Keyvault Secrets

# %%
#Set pipeline secrets using defauly keyvault every AML workspace comes with
print("Setting Pipeline Secrets in Azure Key Vault")

key_vault = ws.get_default_keyvault()
key_vault.set_secret(name="formkey", value=os.getenv('FORM_RECOGNIZER_KEY'))
key_vault.set_secret(name="formendpoint", value=os.getenv('FORM_RECOGNIZER_ENDPOINT'))
key_vault.set_secret(name="formmodelid", value=os.getenv('FORM_RECOGNIZER_CUSTOM_MODEL_ID'))
key_vault.set_secret(name="ocrkey", value=os.getenv('OCR_KEY'))
key_vault.set_secret(name="ocrendpoint", value=os.getenv('OCR_ENDPOINT'))
# Out:
# Setting Pipeline Secrets in Azure Key Vault

# %% [markdown]
# ## Define Pipeline Parameters

# %%
# Just an example how we can use parameters to provide different input folders and values

input_dir = PipelineParameter(name="input_dir", default_value="val/clapperboard")
ocr_output_dir = PipelineParameter(name="ocr_output_dir", default_value="selected_clapperboards")
form_output_dir = PipelineParameter(name="form_output_dir", default_value="form_scoring_test_run")
form_labels = PipelineParameter(name="form_labels",
                                default_value="filename, roll, scene, take, title, director, camera, description")

# %% [markdown]
# ## Build and set up dependencies for task-specific environment

# %%
# Build task-specific environment

from azureml.core.runconfig import RunConfiguration
from azureml.core.conda_dependencies import CondaDependencies

# Create Pipeline run configuration 

run_config = RunConfiguration()
run_config.environment.docker.enabled = True
run_config.environment.python.conda_dependencies = CondaDependencies.create(
    pip_packages=[
        'argparse==1.4.0',
        'azureml-sdk==1.18.0',
        'azure-storage-blob==12.5.0',
        'azure-identity==1.4.1',
        'azure-mgmt-resource==10.2.0',
        'azure-mgmt-network==16.0.0',
        'azure-mgmt-compute==17.0.0',
        'pyjwt==1.7.1',
        'numpy==1.18.5',
        'pandas==1.1.3',
        'pillow==7.2.0',
        'pyarrow==1.0.1',
        'scikit-image==0.17.2',
        'scikit-learn==0.23.2',
        'scipy==1.5.2',
        'tqdm==4.48.2',
        'opencv-python-headless',
        'tensorflow==2.3.0',
        'azure-cognitiveservices-vision-customvision==3.0.0',
        'PyYAML==5.3.1',
        'ipywidgets==7.5.1',
        'click==7.1.2',
        'python-dotenv==0.10.3'
    ]
)

#specify docker image that will be used

dockerfile = r"""
FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1
"""

run_config.environment.docker.base_image = None
run_config.environment.docker.base_dockerfile = dockerfile

# %% [markdown]
# ## Configure and instantiate pipeline steps

# %%
# Create and configure Form Recognizer Training pipeline steps

source_directory = "../"

clapperboard_selection_step = PythonScriptStep(
    name="clapperboard selection",
    script_name="mlops/form_scoring_pipeline/steps/select_clapperboards.py",
    arguments=[
        "--root_dir",
        root_dir,
        "--input_dir",
        input_dir,
        "--output_dir",
        ocr_output_dir,
        "--force",
        True,
    ],
    inputs=[root_dir],
    outputs=[],
    compute_target=compute_target,
    source_directory=source_directory,
    runconfig=run_config,
    allow_reuse=False,
)

form_extraction_step = PythonScriptStep(
    name="form_recognizer",
    script_name="mlops/form_scoring_pipeline/steps/extract_forms.py",
    arguments=[
        "--root_dir",
        root_dir,
        "--input_dir",
        input_dir,
        "--clapperboard_dir",
        ocr_output_dir,
        "--output_dir",
        form_output_dir,
        "--labels",
        form_labels,
        "--force",
        True,
    ],
    inputs=[root_dir],
    outputs=[],
    compute_target=compute_target,
    source_directory=source_directory,
    runconfig=run_config,
    allow_reuse=False,
)

form_extraction_step.run_after(clapperboard_selection_step)

form_postprocessing_step = PythonScriptStep(
    name="postprocessing_form_recognizer",
    script_name="mlops/form_scoring_pipeline/steps/postprocess.py",
    arguments=[
        "--root_dir",
        root_dir,
        "--input_dir",
        form_output_dir,
        "--output_dir",
        form_output_dir,
        "--force",
        True,
    ],
    inputs=[root_dir],
    compute_target=compute_target,
    source_directory=source_directory,
    outputs=[],
    runconfig=run_config,
    allow_reuse=False,
)

form_postprocessing_step.run_after(form_extraction_step)

print("Pipeline Steps Created")
# Out:
# Pipeline Steps Created

# %% [markdown]
# ## Configure and publish pipeline to AML

# %%
# Create pipeline using existing steps
scoring_pipeline = Pipeline(workspace=ws, steps=[clapperboard_selection_step,
                                                 form_extraction_step,
                                                 form_postprocessing_step])

# Check if the pipeline is consistent 
scoring_pipeline.validate()

# Publish pipeline
published_pipeline = scoring_pipeline.publish(
    name = "form_scoring_pipeline",
    description = "Pipeline to score a Custom Form Recognizer model"
)
# Out:
# Step clapperboard selection is ready to be created [0caa62b2]
# Step form_recognizer is ready to be created [10f4d039]
# Step postprocessing_form_recognizer is ready to be created [513be94d]
# Created step clapperboard selection [0caa62b2][3f67f608-12e2-43aa-bd79-e6a7defa27ef], (This step will run and generate new outputs)
# Created step form_recognizer [10f4d039][9306495c-2e45-4c1e-9b5b-9c37e329c998], (This step will run and generate new outputs)
# Created step postprocessing_form_recognizer [513be94d][6b84e4c1-f813-41b4-abc1-a2f5db814dab], (This step will run and generate new outputs)
# Using data reference form_data_ref for StepId [8ac11295][eb3974e4-60a3-418c-a118-01c1fa392c27], (Consumers of this data are eligible to reuse prior runs.)
# Using data reference form_data_ref for StepId [b3a31671][eb3974e4-60a3-418c-a118-01c1fa392c27], (Consumers of this data are eligible to reuse prior runs.)Using data reference form_data_ref for StepId [2b010cff][eb3974e4-60a3-418c-a118-01c1fa392c27], (Consumers of this data are eligible to reuse prior runs.)

# %% [markdown]
# ## Submit and run pipeline in AML

# %%
# Submit the pipeline
pipeline_run = Experiment(ws, 'form-score-pipeline').submit(scoring_pipeline)
pipeline_run.wait_for_completion()
# Out:
# Submitted PipelineRun 7fba0a93-f04c-4f33-b637-40657d8072ab
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/form-score-pipeline/runs/7fba0a93-f04c-4f33-b637-40657d8072ab?wsid=/subscriptions/5eb4ea0a-0c5d-4ed1-8553-b0ee0f5215b7/resourcegroups/iota-sharing-rg/workspaces/sandbox
# PipelineRunId: 7fba0a93-f04c-4f33-b637-40657d8072ab
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/form-score-pipeline/runs/7fba0a93-f04c-4f33-b637-40657d8072ab?wsid=/subscriptions/5eb4ea0a-0c5d-4ed1-8553-b0ee0f5215b7/resourcegroups/iota-sharing-rg/workspaces/sandbox
# PipelineRun Status: Running
#
#
# StepRunId: 9a24aefd-d99e-42f7-932c-1bb88438c4bf
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/form-score-pipeline/runs/9a24aefd-d99e-42f7-932c-1bb88438c4bf?wsid=/subscriptions/5eb4ea0a-0c5d-4ed1-8553-b0ee0f5215b7/resourcegroups/iota-sharing-rg/workspaces/sandbox
# StepRun( clapperboard selection ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_29fbfdbb3f13dbdbc53e133906f29358baa2666ed5b0fea4c9cd14e6b0558a86_p.txt
# ========================================================================================================================
# 2021-04-20T04:19:24Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/workspaceblobstore
# 2021-04-20T04:19:24Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/form_pipe_ds --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/caches/form_pipe_ds --file-cache-timeout-in-seconds=1000000 --cache-size-mb=8223 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/configs/form_pipe_ds.cfg --log-level=LOG_WARNING
# 2021-04-20T04:19:25Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/form_pipe_ds
# 2021-04-20T04:19:25Z Starting output-watcher...
# 2021-04-20T04:19:25Z IsDedicatedCompute == False, starting polling for Low-Pri Preemption
# 2021-04-20T04:19:25Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-04-20T04:19:25Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_491a6f3fa6c545c7caf5bd2dcf493eaa
# Digest: sha256:3be4f5c0bb1e444d4dee5d7c898399d78ba291b04741ec3b59a935212127874f
# Status: Image is up to date for 542377d412d74c64845ef69100365f8c.azurecr.io/azureml/azureml_491a6f3fa6c545c7caf5bd2dcf493eaa:latest
# 542377d412d74c64845ef69100365f8c.azurecr.io/azureml/azureml_491a6f3fa6c545c7caf5bd2dcf493eaa:latest
# 2021-04-20T04:19:26Z Check if container 9a24aefd-d99e-42f7-932c-1bb88438c4bf already exist exited with 0,
#
# 80c27ae1a2ac8af90af6588b83867908846ce639b4386477608fac8f09fdec40
# 2021-04-20T04:19:26Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-04-20T04:19:26Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-59b30a81d61db371b9225b4b1f052491-425f15f6d7ee467b-01 -sshRequired=false]
# 2021/04/20 04:19:26 Starting App Insight Logger for task:  containerSetup
# 2021/04/20 04:19:26 Version: 3.0.01551.0005 Branch: .SourceBranch Commit: 14e0b35
# 2021/04/20 04:19:26 Entered ContainerSetupTask - Preparing infiniband
# 2021/04/20 04:19:26 Starting infiniband setup
# 2021/04/20 04:19:26 VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/04/20 04:19:26 VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-04-20T04:19:26Z VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/04/20 04:19:26 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/04/20 04:19:26 Not setting up Infiniband in Container
# 2021/04/20 04:19:26 Not setting up Infiniband in Container
# 2021-04-20T04:19:26Z Not setting up Infiniband in Container
# 2021/04/20 04:19:26 sshd inside container not required for job, skipping setup.
# 2021/04/20 04:19:27 All App Insights Logs was send successfully
# 2021/04/20 04:19:27 App Insight Client has already been closed
# 2021/04/20 04:19:27 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-04-20T04:19:27Z Starting docker container succeeded.
# 2021-04-20T04:19:40Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2021/04/20 04:19:23 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/04/20 04:19:23 Version: 3.0.01551.0005 Branch: .SourceBranch Commit: 14e0b35
# >>>   2021/04/20 04:19:23 runtime.GOOS linux
# >>>   2021/04/20 04:19:23 Checking if '/tmp' exists
# >>>   2021/04/20 04:19:23 Reading dyanamic configs
# >>>   2021/04/20 04:19:23 Container sas url: https://baiscriptsby1prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=ZjMPBRofQ17k%2BGcGn7fj%2FyqJ0WkeEHN%2BD8H%2BEWhmCnU%3D
# >>>   2021/04/20 04:19:23 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: not a directory
# >>>   2021/04/20 04:19:23 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed true, isEnable true,
# >>>   2021/04/20 04:19:23 azsecpack isEnable:true,GetDisableVsatlsscan:true
# >>>   2021/04/20 04:19:23 start to install azsecpack..., MachineName is b6bf0d3e90f44a8c904717b5a9a543bf000000
# >>>
# >>>   2021/04/20 04:19:23
# >>>   2021/04/20 04:19:23
# >>>   2021/04/20 04:19:23 OS patching disabled by dynamic configs. Skipping.
# >>>   2021/04/20 04:19:23 DetonationChamber is not enabled on this subscription: 5eb4ea0a-0c5d-4ed1-8553-b0ee0f5215b7
# >>>   2021/04/20 04:19:23 Start to getting gpu count by running nvidia-smi command
# >>>   2021/04/20 04:19:23 GPU count found on the node: 0
# >>>   2021/04/20 04:19:23 AMLComputeXDSEndpoint:  https://by1-prodk8ds.batchai.core.windows.net
# >>>   2021/04/20 04:19:23 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/04/20 04:19:23 Creating directory /mnt/batch/tasks/shared/LS_root/jobs
# >>>   2021/04/20 04:19:23 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=8223 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/04/20 04:19:23 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/workspaceblobstore
# >>>   2021/04/20 04:19:24 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/workspaceblobstore
# >>>   2021/04/20 04:19:24 Successfully mounted azureml-blobstore-542377d4-12d7-4c64-845e-f69100365f8c container from sandbox4790804641 account at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/workspaceblobstore
# >>>   2021/04/20 04:19:24 Mounting images container from blobiotasharing account at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/form_pipe_ds
# >>>   2021/04/20 04:19:24 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/04/20 04:19:24 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/04/20 04:19:24 Blobfuse cache size set to 8223 MB.
# >>>   2021/04/20 04:19:24 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/form_pipe_ds --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/caches/form_pipe_ds --file-cache-timeout-in-seconds=1000000 --cache-size-mb=8223 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/configs/form_pipe_ds.cfg --log-level=LOG_WARNING
# >>>   2021/04/20 04:19:25 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/form_pipe_ds
# >>>   2021/04/20 04:19:25 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/form_pipe_ds
# >>>   2021/04/20 04:19:25 Successfully mounted images container from blobiotasharing account at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/form_pipe_ds
# >>>   2021/04/20 04:19:25 No unmanaged file systems configured
# >>>   2021/04/20 04:19:25 Start to getting gpu count by running nvidia-smi command
# >>>   2021/04/20 04:19:25 From the policy service, the filtering patterns is: , data store is
# >>>   2021/04/20 04:19:25 Creating directory /mnt/batch/tasks/shared/LS_root/jobs
# >>>   2021/04/20 04:19:26 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name 9a24aefd-d99e-42f7-932c-1bb88438c4bf -m 6618m -w /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/config/.batchai.envlist --shm-size 2g -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf:/mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf -v /mnt/batch/tasks/workitems/2bff066a-c763-4dd6-9db7-80ab9b1523db/job-1/9a24aefd-d99e-42f7-9_872109d4-ea09-4d60-9191-d8b2a3f02fcc/wd:/mnt/batch/tasks/workitems/2bff066a-c763-4dd6-9db7-80ab9b1523db/job-1/9a24aefd-d99e-42f7-9_872109d4-ea09-4d60-9191-d8b2a3f02fcc/wd -v /mnt/batch/tasks/workitems/2bff066a-c763-4dd6-9db7-80ab9b1523db/job-1/9a24aefd-d99e-42f7-9_872109d4-ea09-4d60-9191-d8b2a3f02fcc/certs:/mnt/batch/tasks/workitems/2bff066a-c763-4dd6-9db7-80ab9b1523db/job-1/9a24aefd-d99e-42f7-9_872109d4-ea09-4d60-9191-d8b2a3f02fcc/certs -d -it --privileged --net=host 542377d412d74c64845ef69100365f8c.azurecr.io/azureml/azureml_491a6f3fa6c545c7caf5bd2dcf493eaa
# >>>   2021/04/20 04:19:26 Check if container 9a24aefd-d99e-42f7-932c-1bb88438c4bf already exist exited with 0,
# >>>
# >>>   2021/04/20 04:19:26 Check if container 9a24aefd-d99e-42f7-932c-1bb88438c4bf already exist exited with 0,
# >>>
# >>>   2021/04/20 04:19:26 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/04/20 04:19:26 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/04/20 04:19:26 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-59b30a81d61db371b9225b4b1f052491-425f15f6d7ee467b-01 -sshRequired=false]
# >>>   2021/04/20 04:19:26 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-59b30a81d61db371b9225b4b1f052491-425f15f6d7ee467b-01 -sshRequired=false]
# >>>   2021/04/20 04:19:27 Container ssh is not required for job type.
# >>>   2021/04/20 04:19:27 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-59b30a81d61db371b9225b4b1f052491-eaa92ff792649a83-01 -t 9a24aefd-d99e-42f7-932c-1bb88438c4bf bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/2bff066a-c763-4dd6-9db7-80ab9b1523db/job-1/9a24aefd-d99e-42f7-9_872109d4-ea09-4d60-9191-d8b2a3f02fcc/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/workspaceblobstore/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf;/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/bin/python /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf/mounts/workspaceblobstore/azureml/9a24aefd-d99e-42f7-932c-1bb88438c4bf-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"984783ca-e006-48c1-9f42-eaf3d55fd30e","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/04/20 04:19:28 Attempt 1 of http call to https://westus.experiments.azureml.net/history/v1.0/private/subscriptions/5eb4ea0a-0c5d-4ed1-8553-b0ee0f5215b7/resourceGroups/iota-sharing-rg/providers/Microsoft.MachineLearningServices/workspaces/sandbox/runs/9a24aefd-d99e-42f7-932c-1bb88438c4bf/spans
# >>>   2021/04/20 04:19:39 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:27.719868] Entering job preparation.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:29.065713] Starting job preparation.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:29.065748] Extracting the control code.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:29.093367] fetching and extracting the control code on master node.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:29.093396] Starting extract_project.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:29.093437] Starting to extract zip file.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:29.817630] Finished extracting zip file.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:30.061164] Using urllib.request Python 3.0 or later
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:30.061203] Start fetching snapshots.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:30.061247] Start fetching snapshot.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:30.061261] Retrieving project from snapshot: 984783ca-e006-48c1-9f42-eaf3d55fd30e
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 49
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:38.972324] Finished fetching snapshot.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:38.972357] Finished fetching snapshots.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:38.972365] Finished extract_project.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:38.984735] Finished fetching and extracting the control code.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:38.987942] downloadDataStore - Download from datastores if requested.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:38.989377] Start run_history_prep.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:39.037605] Entering context manager injector.
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: Acquired lockfile /tmp/9a24aefd-d99e-42f7-932c-1bb88438c4bf-datastore.lock to downloading input data references
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:39.345415] downloadDataStore completed
# >>>   2021/04/20 04:19:39 runSpecialJobTask: preparation: [2021-04-20T04:19:39.348126] Job preparation is complete.
# >>>   2021/04/20 04:19:39 Execution of runSpecialJobTask completed
# >>>   2021/04/20 04:19:39 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/04/20 04:19:39 Process Exiting with Code:  0
# >>>   2021/04/20 04:19:40 All App Insights Logs was send successfully
# >>>
# 2021-04-20T04:19:40Z 127.0.0.1 slots=2 max-slots=2
# 2021-04-20T04:19:40Z launching Custom job
# Streaming azureml-logs/65_job_prep-tvmps_29fbfdbb3f13dbdbc53e133906f29358baa2666ed5b0fea4c9cd14e6b0558a86_p.txt
# ===============================================================================================================
# [2021-04-20T04:19:27.719868] Entering job preparation.
# [2021-04-20T04:19:29.065713] Starting job preparation.
# [2021-04-20T04:19:29.065748] Extracting the control code.
# [2021-04-20T04:19:29.093367] fetching and extracting the control code on master node.
# [2021-04-20T04:19:29.093396] Starting extract_project.
# [2021-04-20T04:19:29.093437] Starting to extract zip file.
# [2021-04-20T04:19:29.817630] Finished extracting zip file.
# [2021-04-20T04:19:30.061164] Using urllib.request Python 3.0 or later
# [2021-04-20T04:19:30.061203] Start fetching snapshots.
# [2021-04-20T04:19:30.061247] Start fetching snapshot.
# [2021-04-20T04:19:30.061261] Retrieving project from snapshot: 984783ca-e006-48c1-9f42-eaf3d55fd30e
# Starting the daemon thread to refresh tokens in background for process with pid = 49
# [2021-04-20T04:19:38.972324] Finished fetching snapshot.
# [2021-04-20T04:19:38.972357] Finished fetching snapshots.
# [2021-04-20T04:19:38.972365] Finished extract_project.
# [2021-04-20T04:19:38.984735] Finished fetching and extracting the control code.
# [2021-04-20T04:19:38.987942] downloadDataStore - Download from datastores if requested.
# [2021-04-20T04:19:38.989377] Start run_history_prep.
# [2021-04-20T04:19:39.037605] Entering context manager injector.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# Acquired lockfile /tmp/9a24aefd-d99e-42f7-932c-1bb88438c4bf-datastore.lock to downloading input data references
# [2021-04-20T04:19:39.345415] downloadDataStore completed
# [2021-04-20T04:19:39.348126] Job preparation is complete.
#
# Streaming azureml-logs/75_job_post-tvmps_29fbfdbb3f13dbdbc53e133906f29358baa2666ed5b0fea4c9cd14e6b0558a86_p.txt
# ===============================================================================================================
# [2021-04-20T04:19:51.701923] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# [2021-04-20T04:19:52.609337] Starting job release
# [2021-04-20T04:19:52.614163] Logging experiment finalizing status in history service.
# [2021-04-20T04:19:52.614572] job release stage : upload_datastore starting...
# [2021-04-20T04:19:52.615313] job release stage : start importing azureml.history._tracking in run_history_release.
# Starting the daemon thread to refresh tokens in background for process with pid = 139
# [2021-04-20T04:19:52.615595] job release stage : execute_job_release starting...
# [2021-04-20T04:19:52.617337] job release stage : copy_batchai_cached_logs starting...
# [2021-04-20T04:19:52.617395] job release stage : copy_batchai_cached_logs completed...
# [2021-04-20T04:19:52.624420] Entering context manager injector.
# [2021-04-20T04:19:52.643828] job release stage : upload_datastore completed...
# [2021-04-20T04:19:52.736084] job release stage : execute_job_release completed...
# [2021-04-20T04:19:52.751724] job release stage : send_run_telemetry starting...
# [2021-04-20T04:19:52.897787] get vm size and vm region successfully.
# [2021-04-20T04:19:53.113723] get compute meta data successfully.
# [2021-04-20T04:19:53.267534] post artifact meta request successfully.
# [2021-04-20T04:19:53.290422] upload compute record artifact successfully.
# [2021-04-20T04:19:53.290517] job release stage : send_run_telemetry completed...
# [2021-04-20T04:19:53.290711] Job release is complete
#
# StepRun(clapperboard selection) Execution Summary
# ==================================================
# StepRun( clapperboard selection ) Status: Finished
# {'runId': '9a24aefd-d99e-42f7-932c-1bb88438c4bf', 'target': 'train-test-clust', 'status': 'Completed', 'startTimeUtc': '2021-04-20T04:19:24.630263Z', 'endTimeUtc': '2021-04-20T04:20:00.494062Z', 'properties': {'ContentSnapshotId': '984783ca-e006-48c1-9f42-eaf3d55fd30e', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '3f67f608-12e2-43aa-bd79-e6a7defa27ef', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '0caa62b2', 'azureml.pipelinerunid': '7fba0a93-f04c-4f33-b637-40657d8072ab', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'mlops/form_scoring_pipeline/steps/select_clapperboards.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--root_dir', '$AZUREML_DATAREFERENCE_form_data_ref', '--input_dir', '$AML_PARAMETER_input_dir', '--output_dir', '$AML_PARAMETER_ocr_output_dir', '--force', 'True'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'train-test-clust', 'dataReferences': {'form_data_ref': {'dataStoreName': 'form_pipe_ds', 'mode': 'Mount', 'pathOnDataStore': '', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment form-score-pipeline Environment', 'version': 'Autosave_2021-04-20T03:08:27Z_dee3578c', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['argparse==1.4.0', 'azureml-sdk~=1.23.0', 'azure-storage-blob==12.5.0', 'azure-identity==1.4.1', 'azure-mgmt-resource==10.2.0', 'azure-mgmt-network==16.0.0', 'azure-mgmt-compute==17.0.0', 'pyjwt==1.7.1', 'numpy==1.18.5', 'pandas==1.1.3', 'pillow==7.2.0', 'pyarrow==1.0.1', 'scikit-image==0.17.2', 'scikit-learn==0.23.2', 'scipy==1.5.2', 'tqdm==4.48.2', 'opencv-python-headless', 'tensorflow==2.3.0', 'azure-cognitiveservices-vision-customvision==3.0.0', 'PyYAML==5.3.1', 'ipywidgets==7.5.1', 'click==7.1.2', 'python-dotenv==0.10.3']}], 'name': 'azureml_87c43497c4d4f72ed3fa76b80566d1b6'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE', 'AML_PARAMETER_input_dir': 'val/clapperboard', 'AML_PARAMETER_ocr_output_dir': 'selected_clapperboards'}, 'docker': {'baseImage': None, 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': '\nFROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1\n', 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments' ...
# StepRunId: 7cc1b284-1c23-4c91-8e54-56b5a5cd5828
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/form-score-pipeline/runs/7cc1b284-1c23-4c91-8e54-56b5a5cd5828?wsid=/subscriptions/5eb4ea0a-0c5d-4ed1-8553-b0ee0f5215b7/resourcegroups/iota-sharing-rg/workspaces/sandbox
# StepRun( form_recognizer ) Status: NotStarted
# StepRun( form_recognizer ) Status: Queued
# StepRun( form_recognizer ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_29fbfdbb3f13dbdbc53e133906f29358baa2666ed5b0fea4c9cd14e6b0558a86_p.txt
# ========================================================================================================================
# 2021-04-20T04:20:20Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/7cc1b284-1c23-4c91-8e54-56b5a5cd5828/mounts/workspaceblobstore
# 2021-04-20T04:20:21Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/7cc1b284-1c23-4c91-8e54-56b5a5cd5828/mounts/form_pipe_ds --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/7cc1b284-1c23-4c91-8e54-56b5a5cd5828/caches/form_pipe_ds --file-cache-timeout-in-seconds=1000000 --cache-size-mb=8223 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/7cc1b284-1c23-4c91-8e54-56b5a5cd5828/configs/form_pipe_ds.cfg --log-level=LOG_WARNING
# 2021-04-20T04:20:21Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/sandbox/azureml/7cc1b284-1c23-4c91-8e54-56b5a5cd5828/mounts/form_pipe_ds
# 2021-04-20T04:20:21Z Starting output-watcher...
# 2021-04-20T04:20:21Z IsDedicatedCompute == False, starting polling for Low-Pri Preemption
# 2021-04-20T04:20:21Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-04-20T04:20:21Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_491a6f3fa6c545c7caf5bd2dcf493eaa
# Digest: sha256:3be4f5c0bb1e444d4dee5d7c898399d78ba291b04741ec3b59a935212127874f
# Status: Image is up to date for 542377d412d74c64845ef69100365f8c.azurecr.io/azureml/azureml_491a6f3fa6c545c7caf5bd2dcf493eaa:latest
# 542377d412d74c64845ef69100365f8c.azurecr.io/azureml/azureml_491a6f3fa6c545c7caf5bd2dcf493eaa:latest
# 2021-04-20T04:20:22Z Check if container 7cc1b284-1c23-4c91-8e54-56b5a5cd5828 already exist exited with 0,
#
# d7e1436722f6298e103201303a2c007193a9f358e9748e5a81a267775ab61605
# 2021-04-20T04:20:22Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-04-20T04:20:22Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-c53e44e028cf71ed5619345afac57adf-80ada06e7bec0290-01 -sshRequired=false]
# 2021/04/20 04:20:22 Starting App Insight Logger for task:  containerSetup
# 2021/04/20 04:20:22 Version: 3.0.01551.0005 Branch: .SourceBranch Commit: 14e0b35
# 2021/04/20 04:20:22 Entered ContainerSetupTask - Preparing infiniband
# 2021/04/20 04:20:22 Starting infiniband setup
# 2021/04/20 04:20:22 VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/04/20 04:20:22 VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-04-20T04:20:22Z VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/04/20 04:20:22 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/04/20 04:20:22 Not setting up Infiniband in Container
# ...
# >>>   2021/04/20 04:21:53 runSpecialJobTask: job postprocessing exited with code 0 and err <nil>
# >>>
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:49.950987] Entering job release
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:50.873969] Starting job release
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:50.878475] Logging experiment finalizing status in history service.
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:50.878688] job release stage : upload_datastore starting...
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: Starting the daemon thread to refresh tokens in background for process with pid = 135
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:50.879125] job release stage : start importing azureml.history._tracking in run_history_release.
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:50.886555] job release stage : execute_job_release starting...
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:50.886801] job release stage : copy_batchai_cached_logs starting...
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:50.886896] job release stage : copy_batchai_cached_logs completed...
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:50.887923] Entering context manager injector.
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:50.906422] job release stage : upload_datastore completed...
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:51.059230] job release stage : execute_job_release completed...
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:51.077989] job release stage : send_run_telemetry starting...
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:51.437969] get vm size and vm region successfully.
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:51.940477] get compute meta data successfully.
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:52.093306] post artifact meta request successfully.
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:52.117727] upload compute record artifact successfully.
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:52.117854] job release stage : send_run_telemetry completed...
# >>>   2021/04/20 04:21:53 runSpecialJobTask: postprocessing: [2021-04-20T04:21:52.118286] Job release is complete
# >>>   2021/04/20 04:21:53 All App Insights Logs was send successfully
# >>>   2021/04/20 04:21:53 App Insight Client has already been closed
# >>>   2021/04/20 04:21:53 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>
# 2021-04-20T04:21:53Z Executing 'Job environment clean-up' on 10.0.0.4
# 2021-04-20T04:21:53Z Removing container bdb0de07-81b3-4a13-ab89-4ead1dfbcd6c exited with 0, bdb0de07-81b3-4a13-ab89-4ead1dfbcd6c
# Streaming azureml-logs/75_job_post-tvmps_29fbfdbb3f13dbdbc53e133906f29358baa2666ed5b0fea4c9cd14e6b0558a86_p.txt
# ===============================================================================================================
# [2021-04-20T04:21:49.950987] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.4.7 (/azureml-envs/azureml_87c43497c4d4f72ed3fa76b80566d1b6/lib/python3.6/site-packages), Requirement.parse('cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<=3.2')).
# [2021-04-20T04:21:50.873969] Starting job release
# [2021-04-20T04:21:50.878475] Logging experiment finalizing status in history service.
# [2021-04-20T04:21:50.878688] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 135
# [2021-04-20T04:21:50.879125] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-04-20T04:21:50.886555] job release stage : execute_job_release starting...
# [2021-04-20T04:21:50.886801] job release stage : copy_batchai_cached_logs starting...
# [2021-04-20T04:21:50.886896] job release stage : copy_batchai_cached_logs completed...
# [2021-04-20T04:21:50.887923] Entering context manager injector.
# [2021-04-20T04:21:50.906422] job release stage : upload_datastore completed...
# [2021-04-20T04:21:51.059230] job release stage : execute_job_release completed...
# [2021-04-20T04:21:51.077989] job release stage : send_run_telemetry starting...
# [2021-04-20T04:21:51.437969] get vm size and vm region successfully.
# [2021-04-20T04:21:51.940477] get compute meta data successfully.
# [2021-04-20T04:21:52.093306] post artifact meta request successfully.
# [2021-04-20T04:21:52.117727] upload compute record artifact successfully.
# [2021-04-20T04:21:52.117854] job release stage : send_run_telemetry completed...
# [2021-04-20T04:21:52.118286] Job release is complete
#
# StepRun(postprocessing_form_recognizer) Execution Summary
# ==========================================================
# StepRun( postprocessing_form_recognizer ) Status: Finished
# {'runId': 'bdb0de07-81b3-4a13-ab89-4ead1dfbcd6c', 'target': 'train-test-clust', 'status': 'Completed', 'startTimeUtc': '2021-04-20T04:21:22.542479Z', 'endTimeUtc': '2021-04-20T04:22:00.714045Z', 'properties': {'ContentSnapshotId': '984783ca-e006-48c1-9f42-eaf3d55fd30e', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '6b84e4c1-f813-41b4-abc1-a2f5db814dab', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '513be94d', 'azureml.pipelinerunid': '7fba0a93-f04c-4f33-b637-40657d8072ab', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'mlops/form_scoring_pipeline/steps/postprocess.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--root_dir', '$AZUREML_DATAREFERENCE_form_data_ref', '--input_dir', '$AML_PARAMETER_form_output_dir', '--output_dir', '$AML_PARAMETER_form_output_dir', '--force', 'True'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'train-test-clust', 'dataReferences': {'form_data_ref': {'dataStoreName': 'form_pipe_ds', 'mode': 'Mount', 'pathOnDataStore': '', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment form-score-pipeline Environment', 'version': 'Autosave_2021-04-20T04:21:10Z_95ace9c5', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['argparse==1.4.0', 'azureml-sdk~=1.23.0', 'azure-storage-blob==12.5.0', 'azure-identity==1.4.1', 'azure-mgmt-resource==10.2.0', 'azure-mgmt-network==16.0.0', 'azure-mgmt-compute==17.0.0', 'pyjwt==1.7.1', 'numpy==1.18.5', 'pandas==1.1.3', 'pillow==7.2.0', 'pyarrow==1.0.1', 'scikit-image==0.17.2', 'scikit-learn==0.23.2', 'scipy==1.5.2', 'tqdm==4.48.2', 'opencv-python-headless', 'tensorflow==2.3.0', 'azure-cognitiveservices-vision-customvision==3.0.0', 'PyYAML==5.3.1', 'ipywidgets==7.5.1', 'click==7.1.2', 'python-dotenv==0.10.3']}], 'name': 'azureml_87c43497c4d4f72ed3fa76b80566d1b6'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE', 'AML_PARAMETER_form_output_dir': 'form_scoring_test_run'}, 'docker': {'baseImage': None, 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': '\nFROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1\n', 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'co ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '7fba0a93-f04c-4f33-b637-40657d8072ab', 'status': 'Completed', 'startTimeUtc': '2021-04-20T04:19:08.674563Z', 'endTimeUtc': '2021-04-20T04:22:04.148091Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{"input_dir":"val/clapperboard","ocr_output_dir":"selected_clapperboards","form_output_dir":"form_scoring_test_run","form_labels":"filename, roll, scene, take, title, director, camera, description"}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://sandbox4790804641.blob.core.windows.net/azureml/ExperimentRun/dcid.7fba0a93-f04c-4f33-b637-40657d8072ab/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=2bmKYSRlsIoXzcaPIAOYzwlmawyqg%2Fs8kNV%2BGMsge0A%3D&st=2021-04-20T04%3A12%3A06Z&se=2021-04-20T12%3A22%3A06Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://sandbox4790804641.blob.core.windows.net/azureml/ExperimentRun/dcid.7fba0a93-f04c-4f33-b637-40657d8072ab/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=e9a7WE%2F8WLTfE7sceSDv%2FR60%2FHERdHYKVo%2F10vG4rYg%3D&st=2021-04-20T04%3A12%3A06Z&se=2021-04-20T12%3A22%3A06Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://sandbox4790804641.blob.core.windows.net/azureml/ExperimentRun/dcid.7fba0a93-f04c-4f33-b637-40657d8072ab/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=bvXTQS52Sov%2FCWTc1%2BGg%2BXCYdObhNUci3z7lfGan%2BqM%3D&st=2021-04-20T04%3A12%3A06Z&se=2021-04-20T12%3A22%3A06Z&sp=r'}, 'submittedBy': 'Daniel Fatade'}
# 'Finished'
